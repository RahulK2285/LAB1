# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulK2285/LAB1/blob/main/LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Data Exploration

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
y = iris.target

iris_df = pd.DataFrame(X, columns=iris.feature_names)
iris_df['species'] = y

display(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='species', data=iris_df)
plt.title('Distribution of Iris Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.xticks([0, 1, 2], iris.target_names)
plt.show()

sns.pairplot(iris_df, hue='species', palette='husl', diag_kind='kde')
plt.show()

# %% [markdown]
# ### Model Building

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")
# Out:
# Training set shape: (112, 4)
# Testing set shape: (38, 4)

# %%
# Train KNN models with different k values and evaluate accuracy
k_values = [1, 3, 5, 7]
accuracy_scores = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracy)
    print(f"Accuracy with k={k}: {accuracy:.4f}")

best_k_index = accuracy_scores.index(max(accuracy_scores))
best_k = k_values[best_k_index]
print(f"\nBest k value: {best_k} with accuracy: {accuracy_scores[best_k_index]:.4f}")
# Out:
# Accuracy with k=1: 1.0000
# Accuracy with k=3: 1.0000
# Accuracy with k=5: 1.0000
# Accuracy with k=7: 1.0000
#
# Best k value: 1 with accuracy: 1.0000
